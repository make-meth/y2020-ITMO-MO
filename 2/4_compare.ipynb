# %% [markdown]
# ### Сравнение алгоритмов по памяти, времени, надёжности и сходимости.

# %% [markdown]
# #### Память
# Потребление памяти у всех методов примерно одинаковое (минимальное)

# %% [markdown]
# #### Время
#
# Время работы тоже не сильно отличаются.

# %% [markdown]
# #### Надёжность и сходимость
#
# Лучшую сходимость и надёжность показывают Adam, AdaGrad и RMSProp.
#
# Худшую сходимость демонстрирует метод момента.

# %%
from mods import *

# %%
line = test_line(2, 50, 10, 20, 5)

# %%
line
# Out:
# (array([[  84.50652119],
#         [ -34.08786614],
#         [ -44.19859844],
#         [ -67.66739833],
#         [  15.6696341 ],
#         [  84.47674303],
#         [ -60.21515329],
#         [  70.02353292],
#         [  69.61981365],
#         [  78.26263498],
#         [ -54.42757373],
#         [  25.94513109],
#         [ -37.85520028],
#         [  51.77020513],
#         [  34.16651202],
#         [ -65.65143999],
#         [ -54.22670674],
#         [-140.03354985],
#         [   2.54403703],
#         [ -33.55131631],
#         [  67.67637933],
#         [-136.94983661],
#         [-112.75426452],
#         [  91.45521859],
#         [  95.18793412],
#         [  55.2147771 ],
#         [  61.44926024],
#         [   8.8238898 ],
#         [  41.37199638],
#         [-109.70064856],
#         [-122.35875584],
#         [ -12.87011622],
#         [  38.95695709],
#         [-118.31701802],
#         [ -97.45079019],
#         [-106.37983803],
#         [  -9.34183957],
#         [ -65.28052877],
#         [  57.40230837],
#         [-128.12411604],
#         [ -43.77156158],
#         [-125.81618779],
#         [  92.27847527],
#         [ -34.98709025],
#         [  41.0779556 ],
#         [ -83.95081251],
#         [  46.47629404],
#         [-127.770631  ],
#         [ 103.9520959 ],
#         [ -94.18450739]]),
#  array([ -99.23412832,    3.42087579,    3.51308672,   32.59755125,
#          -44.26586349,  -97.13307831,   18.4735268 ,  -84.68117707,
#          -84.59462273,  -97.97733651,   14.82028287,  -55.17085462,
#            4.68162037,  -81.41119347,  -57.68908507,   31.15118534,
#           18.71369844,   91.81650884,  -32.90148518,    3.56108874,
#          -81.7288462 ,   92.71458648,   66.55041388, -104.39411142,
#         -112.59470933,  -78.47206689,  -79.26965877,  -37.37935041,
#          -59.73634704,   64.81435658,   77.45849031,  -16.77386295,
#          -60.25326073,   76.40686422,   53.06074713,   64.57438539,
#          -22.28276578,   30.34845247,  -74.3379387 ,   89.50518678,
#           10.63656754,   83.18558281, -114.02243435,   -3.99533457,
#          -56.12273584,   45.96613225,  -68.12864055,   82.20193099,
#         -127.13634975,   50.40005271]))

# %%
regression(*line, batch_size = 10, lr0=0.01, d=0.1, epoch=1000)
# Out:
# came close by 204.0139143568542
# array([ 0.8114678 , -0.76108761])

# %%
regression(*line, batch_size = 10, method=sgd_momentum, lr0=0.01, epoch=1000, alpha=0.00)
# Out:
# came close by 194.04300812307326
# array([-8.31849833, -1.05572128])

# %%
regression(*line, batch_size = 10, method=sgd_ada_grad, lr0=0.5, epoch=1000)
# Out:
# came close by 26.46276444541907
# array([-27.63604511,  -0.86522799])

# %%
regression(*line, batch_size = 10, method=sgd_rms_prop, lr0=0.1, epoch=1000, alpha=0.5)
# Out:
# came close by 45.44831066780615
# array([-27.99272172,  -0.9332756 ])

# %%
regression(*line, batch_size = 10, method=sgd_adam, lr0=0.01, epoch=100, alpha=0.2, beta=0.2)
# Out:
# came close by 429.10224753511693
# array([ 0.64621847, -0.10175263])

# %%
regression(*line, batch_size = 10, method=sgd_nesterov, lr0=0.001, epoch=100, alpha=0.9)
# Out:
# came close by 441.9426501802454
# array([ 0.29491064, -1.50701412])
